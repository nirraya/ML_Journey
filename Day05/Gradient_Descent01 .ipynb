# %% [markdown]
# ## It's **Nir Bahadur Raya.** It's March 24, 2023. Today, I learned about Gradient Descent. I calculated the intercept value using gradient descent algorithm by keeping the slope constant.

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_regression

# %%
X,y=make_regression(n_samples=100, n_features=1, n_informative=1, n_targets=1, noise=20)

# %%
plt.scatter(X,y)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
lr.fit(X,y)
print(lr.coef_)
print(lr.intercept_)
# Out:
# [65.44540528]
# 1.9662214502920006

# %%
m=65.45

# %%
class GDRegressor:

    def __init__(self,learning_rate,epochs):
        self.m=65.45
        self.b=100
        self.lr=learning_rate 
        self.epochs=epochs
    
    def fit(self,X,y):
        for i in range(self.epochs):
            loss_slope=-2*np.sum(y-self.m*X.ravel()-self.b)
            self.b=self.b-(self.lr*loss_slope)
            print(loss_slope,self.b)
        print(self.b)

# %%
gd=GDRegressor(0.001,200)

# %%
gd.fit(X,y)   #eutai values ma ghumi rakho vaney decrease learning rate and increase epochs
# Out:
# 19606.760217036743 80.39323978296326
# 15685.408173629397 64.70783160933387
# 12548.326538903517 52.15950507043035
# 10038.661231122813 42.12084383930754
# 8030.928984898251 34.08991485440929
# 6424.743187918601 27.665171666490686
# 5139.79455033488 22.525377116155806
# 4111.835640267906 18.4135414758879
# 3289.4685122143233 15.124072963673576
# 2631.5748097714586 12.492498153902117
# 2105.2598478171676 10.38723830608495
# 1684.2078782537337 8.703030427831216
# 1347.366302602987 7.355664125228229
# 1077.8930420823892 6.277771083145839
# 862.3144336659115 5.415456649479927
# 689.8515469327292 4.725605102547198
# 551.8812375461835 4.173723865001015
# 441.5049900369467 3.732218874964068
# 353.20399202955736 3.3790148829345106
# 282.5631936236457 3.096451689310865
# 226.0505548989166 2.8704011344119484
# 180.84044391913343 2.689560690492815
# 144.67235513530647 2.5448883353575087
# 115.73788410824537 2.429150451249263
# 92.59030728659631 2.336560143962667
# ...
