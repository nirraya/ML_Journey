# %% [markdown]
# # It's March 20, 2023. I am learning about Simple Linear Regression.

# %% [markdown]
# <span style="font-size:20px;">I made a simple model that predicts the placement exam marks on the basis of the cgpa.</span>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
class LR:
    def __init__(self):
        self.m=None
        self.b=None
    
    def fit(self,X_train,y_train):
        num=0
        den=0
        
        for i in range(X_train.shape[0]):
            num= num + (X_train[i]- X_train.mean()) * (y_train[i] - y_train.mean())
            den= den + (X_train[i]- X_train.mean()) * (X_train[i] - X_train.mean())
            
        self.m=num/den
        self.b=y_train.mean()-( self.m * X_train.mean())
        
        print(f"m: {self.m}")
        print(f"b: {self.b}")
        
    def predict(self,X_test):
        return self.m * X_test+ self.b

# %%
df=pd.read_csv("placement.csv")
print(df.head(5))
# Out:
#    cgpa  placement_exam_marks  placed
# 0  7.19                  26.0       1
# 1  7.46                  38.0       1
# 2  7.54                  40.0       1
# 3  6.42                   8.0       1
# 4  7.23                  17.0       0

# %%
X=df.iloc[:,0].values

# %%
X
# Out:
# array([7.19, 7.46, 7.54, 6.42, 7.23, 7.3 , 6.69, 7.12, 6.45, 7.75, 6.82,
#        6.38, 6.58, 5.68, 7.91, 7.1 , 6.53, 7.56, 6.93, 7.63, 6.69, 7.43,
#        6.76, 6.05, 6.44, 6.28, 7.45, 6.53, 7.23, 6.51, 7.46, 7.66, 5.91,
#        6.23, 8.15, 7.48, 6.85, 8.51, 6.58, 7.25, 6.6 , 6.7 , 7.46, 7.85,
#        7.88, 6.92, 7.3 , 6.92, 6.29, 8.23, 6.2 , 6.24, 7.53, 6.69, 8.42,
#        8.12, 6.93, 7.73, 7.34, 7.7 , 7.94, 7.51, 7.61, 6.22, 6.98, 6.27,
#        6.67, 8.04, 6.58, 7.41, 6.98, 6.13, 7.9 , 6.39, 6.16, 6.77, 8.35,
#        7.1 , 8.2 , 7.63, 6.87, 7.12, 7.22, 7.38, 5.65, 6.03, 7.19, 6.96,
#        6.78, 6.56, 7.61, 7.42, 6.48, 7.  , 7.15, 6.89, 7.09, 7.33, 8.12,
#        7.46, 6.56, 6.48, 5.92, 6.44, 6.82, 6.72, 6.59, 7.32, 5.94, 7.23,
#        6.96, 6.48, 7.23, 7.24, 6.3 , 7.28, 7.16, 7.11, 6.9 , 7.  , 6.99,
#        5.91, 5.97, 6.25, 6.2 , 7.46, 7.16, 6.95, 6.76, 6.81, 5.91, 8.19,
#        7.71, 7.65, 6.33, 6.63, 7.28, 5.69, 7.53, 8.09, 6.85, 7.19, 7.66,
# ...

# %%
y=df.iloc[:,1].values

# %%
y
# Out:
# array([ 26.,  38.,  40.,   8.,  17.,  23.,  11.,  39.,  38.,  94.,  16.,
#          7.,  16.,  26.,  43.,  21.,  19.,  22.,  27.,  29.,  47.,  33.,
#         54.,  11.,  11.,  58.,   8.,  46.,  19.,  15.,  16.,  44.,  11.,
#         27.,   9.,  12.,  16.,   9.,  20.,  17.,  86.,  38.,  71.,  63.,
#         55.,  10.,  15.,  46.,  42.,  28.,  18.,  28.,  27.,  33.,  36.,
#         15.,  15.,  24.,  43.,  32.,  31.,  86.,  22.,  26.,  52.,  28.,
#         31.,  18.,  30.,  44.,  17.,  20.,  19.,  12.,   3.,  56.,  12.,
#         28.,  12.,  19.,  46.,  44.,  12.,  20.,  35.,  28.,  22.,  19.,
#         39.,  17.,  15.,   6.,  63.,  30.,  21.,  35.,  28.,  52.,  76.,
#         23.,  46.,  26.,  22.,  18.,  47.,  12.,  22.,   9.,  10.,  21.,
#         31.,  33.,  15.,  10.,  77.,  37.,  21.,   0.,  54.,  39.,  46.,
#         27.,  51.,  52.,  30.,  55.,  37.,  23.,  25.,  39.,  53.,  19.,
#         18.,  64.,  93.,  47.,  15.,  53.,   8.,   5.,  22.,  18.,  41.,
# ...

# %%
plt.scatter(X,y)
plt.xlabel("CGPA",fontsize=15)
plt.ylabel("Placement Exam Marks",fontsize=15)
plt.title("CGPA Vs Placement Exam Marks",fontsize=20)
# Out:
# Text(0.5, 1.0, 'CGPA Vs Placement Exam Marks')

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=2)

# %%
X_train.shape
# Out:
# (800,)

# %%
lr=LR()

# %%
lr.fit(X_train,y_train)
# Out:
# m: -0.26502454516087415
# b: 33.97578341892782

# %%
X_test[0]
# Out:
# 8.51

# %%
print(f"The predicted placement exam marks is: {lr.predict(X_test[0])}")
# Out:
# The predicted placement exam marks is: 31.72042453960878

# %%
X_test[0]*(-0.26502454516087415)+ 33.97578341892782
# Out:
# 31.72042453960878

# %%
print(X[0],y[0])
# Out:
# 7.19 26.0

# %%
lr.predict(X[0])
# Out:
# 32.07025693922113

# %%
lr = LR()
lr.fit(X, y)

# predict the y values for each x value in the dataset
y_pred = lr.predict(X)

# plot the scatter plot
plt.scatter(X, y)

# plot the line of best fit
plt.plot(X, y_pred, color='red')

# add x label, y label and title
plt.xlabel('CGPA')
plt.ylabel('Placement Exam Marks')
plt.title('Relationship between CGPA and Placement Exam Marks')

plt.show()
# Out:
# m: -0.8501867444226203
# b: 38.14335397274452
